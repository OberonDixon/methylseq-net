# %%
from methylseqnet import dna_io, inference, metrics, peaks
import methylseqnet
from dimelo import load_processed, plot_enrichment_profile, utils
from matplotlib import pyplot as plt
import torch
import numpy as np
from Bio import motifs, Seq
from Bio.motifs.matrix import PositionWeightMatrix
import pysam
from tqdm.auto import tqdm
from pathlib import Path
from sklearn.metrics import accuracy_score, precision_score, recall_score, precision_recall_curve, auc, f1_score, roc_curve
from matplotlib.ticker import MultipleLocator

# %%
# utils.bed_from_regions_dict(
#     utils.regions_dict_from_input(
#     regions='/clusterfs/rosalind/groups/streetslab/amaslan/nanopore/paper/ctcf/ref/ENCFF797SDL.chm13.bed',
#     window_size=64,
#     ),
#     '/clusterfs/nilah/oberon/datasets/ctcf_peaks/ENCFF797SDL_128.chm13.bed')
# utils.bed_from_regions_dict(
#     utils.regions_dict_from_input(
#         regions='/clusterfs/rosalind/groups/streetslab/amaslan/nanopore/paper/ctcf/ref/ENCFF797SDL.chm13.bed',
#         window_size=256,
#     ),
#     '/clusterfs/nilah/oberon/datasets/ctcf_peaks/ENCFF797SDL_512.chm13.bed'
# )

# %%
ref_genome = '/clusterfs/nilah/oberon/jupyter/chm13.draft_v1.0.fasta'
hg19_genome = '/clusterfs/nilah/oberon/genomes/hg19.fa'
CpG_pileup = '/clusterfs/nilah/oberon/datasets/deep_ctcf/cpg_bam_whole_genome/pileup.sorted.bed.gz'
mA_pileup = '/clusterfs/nilah/oberon/datasets/deep_ctcf/allcontext_bam_whole_genome/pileup.sorted.bed.gz'

# %%
pileup_hp1_nmp = '/clusterfs/nilah/oberon/datasets/deep_ctcf/phased/chrX_hp1_processed/pileup.sorted.bed.gz'
pileup_hp2_nmp = '/clusterfs/nilah/oberon/datasets/deep_ctcf/phased/chrX_hp2_processed/pileup.sorted.bed.gz'
pileup_hp1 = '/clusterfs/nilah/oberon/datasets/deep_ctcf/phased/megalodon/hp1_cpg/pileup.sorted.bed.gz'
pileup_hp2 = '/clusterfs/nilah/oberon/datasets/deep_ctcf/phased/megalodon/hp2_cpg/pileup.sorted.bed.gz'
pileup_hp1_allcontext = '/clusterfs/nilah/oberon/datasets/deep_ctcf/phased/megalodon/hp1_ma/pileup.sorted.bed.gz'
pileup_hp2_allcontext = '/clusterfs/nilah/oberon/datasets/deep_ctcf/phased/megalodon/hp2_ma/pileup.sorted.bed.gz'

# %%
model_paths = [
    '/clusterfs/nilah/oberon/datasets/methylseq-net_deep-ctcf/models/bd417dd_2024-05-20_14-12-34_in4',
    '/clusterfs/nilah/oberon/datasets/methylseq-net_deep-ctcf/models/bd417dd_2024-05-20_14-13-35_in5',
    '/clusterfs/nilah/oberon/datasets/methylseq-net_deep-ctcf/models/bd417dd_2024-05-20_14-33-39_in1',
]

# %%
models = [inference.load_for_eval(model_path) for model_path in model_paths]

# %%
chromosome = 'chrX'
# start = 130_064_000 - 20_000
# end = 130_080_000 + 20_000
# start = 130_080_000
# end = 130_100_000
start = 129_998_000
end = 130_003_120
# start = 37_728_599
# end = 37_733_817

# %%
matches, contig_length = methylseqnet.motifs.find_motifs(
    genome_fasta=ref_genome,
    motif_pfm='/clusterfs/nilah/oberon/datasets/motifs/MA0139.1_forward.pfm',
    chromosome=chromosome,
    start=0,
    end=1000000000,
)

# %%
pwm_matches = ([(match[0]-50,match[0]+50) for match in matches if match[0]>start and match[0]<end and match[1]>0])
print(pwm_matches)
# Out:
# [(129997977, 129998077), (129998223, 129998323), (129998397, 129998497), (129998456, 129998556), (129998601, 129998701), (129999580, 129999680), (129999953, 130000053), (130001185, 130001285), (130001419, 130001519), (130002038, 130002138), (130002454, 130002554), (130002496, 130002596), (130002563, 130002663), (130002613, 130002713), (130002625, 130002725), (130002724, 130002824), (130002799, 130002899), (130002849, 130002949)]

# %%
# bed_motif_ranges = []
# with open('/clusterfs/rosalind/groups/streetslab/amaslan/nanopore/paper/ctcf/ref/ctcf.motifs.known.chm13.bed','r') as f:
#     for line in f:
#         fields = line.split('\t')
#         if fields[0]==chromosome:
#             bed_motif_ranges.append((int(fields[1]),int(fields[2])))

# %%
# ref_fasta = pysam.FastaFile(ref_genome)
# matches = list(forward_pwm.search(Seq.Seq(ref_fasta.fetch(chromosome,start,end))))
# match_positions = []
# match_values = []
# for match in matches:
#     if match[0]>0:
#         match_positions.append(match[0]//128)
#         match_values.append(match[1])
# plt.plot(match_positions,match_values)

# %%
onehot_inputs = []
onehot_hp1 = []
onehot_hp2 = []
for chunk_start in range(start,end,128):
    onehot_inputs.append(
        dna_io.one_hot_dna_from_file(
            chromosome=chromosome,
            start=chunk_start,
            end=chunk_start + 896,
            ref_genome=ref_genome,
            cpg=True,
            cpg_bedmethyl=CpG_pileup,
            ablate_list=pwm_matches,
        )
    )
    onehot_hp1.append(
        dna_io.one_hot_dna_from_file(
            chromosome=chromosome,
            start=chunk_start,
            end=chunk_start + 896,
            ref_genome=ref_genome,
            cpg=True,
            cpg_bedmethyl=pileup_hp1,
            ablate_list=pwm_matches,
        )
    )
    onehot_hp2.append(
        dna_io.one_hot_dna_from_file(
            chromosome=chromosome,
            start=chunk_start,
            end=chunk_start + 896,
            ref_genome=ref_genome,
            cpg=True,
            cpg_bedmethyl=pileup_hp2,
            ablate_list=pwm_matches,
        )
    )

# %%
region = f'{chromosome}:{start}-{end}'
plot_enrichment_profile.plot_enrichment_profile(
    mod_file_names = [pileup_hp1_allcontext,pileup_hp2_allcontext],#CpG_pileup,pileup_hp1,pileup_hp2,pileup_hp1_nmp,pileup_hp2_nmp],
    regions_list = [region,region],#region,region,region,region,region],
    sample_names = ['hp1 ctcf','hp2 ctcf'],#'cpg only','hp1 cpg','hp2 cpg','hp1 guppy','hp2 guppy'],
    motifs = ['A,0','A,0'],#'CG,0','CG,0','CG,0','CG,0','CG,0'],
    window_size = None,
    smooth_window = 500,
)
plt.title('CTCF DiMeLo signal (all context mA caller)')
plt.show()
plot_enrichment_profile.plot_enrichment_profile(
    mod_file_names = [pileup_hp1,pileup_hp2],#pileup_hp1_nmp,pileup_hp2_nmp],
    regions_list = [region,region],#region,region],
    sample_names = ['hp1 cpg','hp2 cpg'],#'hp1 guppy','hp2 guppy'],
    motifs = ['CG,0','CG,0'],#'CG,0','CG,0'],
    window_size = None,
    smooth_window = 500,
)
plt.title('CpG methylation signal (CpG-only caller)')
plt.show()
plot_enrichment_profile.plot_enrichment_profile(
    mod_file_names = [CpG_pileup],#pileup_hp1,pileup_hp2],#pileup_hp1_nmp,pileup_hp2_nmp],
    regions_list = [region],#region,region],#region,region],
    sample_names = ['cpg only'],#'hp1 cpg','hp2 cpg'],#'hp1 guppy','hp2 guppy'],
    motifs = ['CG,0'],#'CG,0','CG,0'],#'CG,0','CG,0'],
    window_size = None,
    smooth_window = 500,
)
plt.title('CpG methylation, combined haplotypes')
plt.show()
# samtools view -N qnames_list.txt -o filtered_output.bam input.bam, requires samtools 1.12 or greater

# %%
# print(np.array(onehot_hp2).shape)
# print(np.array(onehot_hp2).shape)
# onehot_hp2 = np.array(onehot_hp2)
# onehot_hp2[:,:,-1] = 0.7
for idx,model in enumerate(models):
    # for onehot in [onehot_inputs,onehot_hp1,onehot_hp2]:
    name = model_paths[idx][-1]
    if name=='4':
        mod_name = 'seq only'
    elif name=='5':
        mod_name = 'seq+methyl'
    elif name=='1':
        mod_name = 'methyl only'
    else:
        mod_name = name
    predictions_hp1 = torch.sigmoid(model(torch.tensor(np.transpose(np.array(onehot_hp1), (0,2,1)),dtype=torch.float32)).detach())
    predictions_hp2 = torch.sigmoid(model(torch.tensor(np.transpose(np.array(onehot_hp2), (0,2,1)),dtype=torch.float32)).detach())
    x_values = range(start,end,(end-start)//len(predictions_hp1))
    fig, ax = plt.subplots()
    ax.plot(x_values,np.array(predictions_hp1),label='hp1 ctcf')
    ax.plot(x_values,np.array(predictions_hp2),label='hp2 ctcf')
    ax.set_ylim([0,1])
    ax.set_title(mod_name)
    ax.set_xlabel('chrX coordinates')
    ax.set_ylabel('probability of CTCF peak')
    ax.legend()
    ax.xaxis.set_major_locator(MultipleLocator(5000))
    # # plt.plot(match_positions,match_values)
    plt.show()

# %%
model_results_dict = {}

# %%
matches, contig_length = methylseqnet.motifs.find_ctcf_motifs(
    genome_fasta=ref_genome,
    # motif_pfm='/clusterfs/nilah/oberon/datasets/motifs/MA0139.1_forward.pfm',
    chromosome='chr19',
    start=0,
    end=1000000000,
)
matches_pseudo, contig_length = methylseqnet.motifs.find_motifs(
    genome_fasta=ref_genome,
    motif_pfm='/clusterfs/nilah/oberon/datasets/motifs/MA0139.1_forward.pfm',
    chromosome='chr19',
    start=0,
    end=1000000000,
)
max_by_bin = methylseqnet.motifs.bin_and_max(
    matches=matches,
    bin_size=128,
    contig_length=contig_length
)

# %%
bed_matches = []
with open('/clusterfs/rosalind/groups/streetslab/amaslan/nanopore/paper/ctcf/ref/ctcf.motifs.known.chm13.bed','r') as f:
    for line in f:
        fields = line.split('\t')
        if fields[0]=='chr19':
            bed_matches.append((int(fields[1])+int(fields[2]))//2)
bed_matches = [(bed_match,12) for bed_match in bed_matches]

# %%
max_by_bin_bed = methylseqnet.motifs.bin_and_max(
    matches=bed_matches,
    bin_size=128,
    contig_length=contig_length
)

# %%
# thresh = 13.2
# num_to_print = 100
# matches_thresholded = [match[0] for match in matches if match[1]>thresh]
# matches_pseudo_thresholded = [match[0] for match in matches_pseudo if match[1]>thresh]
# print(len(bed_matches))
# print(len(matches_thresholded))
# print(len(matches_pseudo_thresholded))
# print(bed_matches[0:num_to_print])
# print(matches_thresholded[0:num_to_print])
# print(matches_pseudo_thresholded[0:num_to_print])

# %%
# Out:
# {'accuracy': 0.9915368148553791, 'precision': 0.09133932796971131, 'recall': 0.08202294942626434, 'f1': 0.0864308105687416, 'prc_auc': 0.088921393589211}

# %%
mA_pileup = '/clusterfs/nilah/oberon/datasets/deep_ctcf/allcontext_bam_whole_genome/pileup.sorted.bed.gz'
chr19_peaks = peaks.peaks_from_bedmethyl(
    bedmethyl_file=mA_pileup,
    fasta_file=ref_genome,
    chromosome='chr19',
    bin_size=128,
    threshold=0.05,
)
print(len(chr19_peaks))
print(sum(chr19_peaks))
# Out:
# 482088
# 6512

# %%
print(metrics.all_metrics(chr19_peaks,max_by_bin_bed/15))
# Out:
# {'accuracy': 0.9841253049235824, 'precision': 0.23000473260766682, 'recall': 0.07463144963144963, 'f1': 0.11269565217391304, 'prc_auc': 0.158567987404054}

# %%
# print(sum(chr19_peaks))
model_results_dict['motif PWM'] = (chr19_peaks,max_by_bin)
model_results_dict['motif annotation'] = (chr19_peaks,max_by_bin_bed)

# %%
print(metrics.all_metrics(*model_results_dict['canonical_motif']))
# Out:
# {'accuracy': 0.9915368148553791, 'precision': 0.09133932796971131, 'recall': 0.08202294942626434, 'f1': 0.0864308105687416, 'prc_auc': 0.088921393589211}

# %%
# chrX_dataset = '/clusterfs/nilah/oberon/datasets/methylseq-net_deep-ctcf/chrX_ALL_th0.05_56cb7b6.h5'
# targets,probabilities = inference.run_whole_dataset(
#     model_paths[1],
#     chrX_dataset,
# )
# print(metrics.all_metrics(targets,probabilities))

# %%
# test_dataset = '/clusterfs/nilah/oberon/datasets/methylseq-net_deep-ctcf/test_th0.05_fd6d75e.h5'
# test_targets,test_probabilities = inference.run_whole_dataset(
#     model_paths[1],
#     test_dataset,
# )
# print(metrics.all_metrics(test_targets,test_probabilities))

# %%
chr19_dataset = '/clusterfs/nilah/oberon/datasets/methylseq-net_deep-ctcf/chr19_ALL_th0.05_56cb7b6.h5'
for model_path in model_paths:
    name = Path(model_path).stem[-1]+"_channel"
    print(name)
    model_results_dict[name] = inference.run_whole_dataset(
        model_path,
        chr19_dataset,
    )
# Out:
# 4_channel
# model passes:   0%|          | 0/471 [00:00<?, ?batch/s]
# 5_channel
# model passes:   0%|          | 0/471 [00:00<?, ?batch/s]
# 1_channel
# model passes:   0%|          | 0/471 [00:00<?, ?batch/s]

# %%
# Get the length of the existing array
length = len(chr19_peaks)

# Calculate the number of values that should be above 0.5
num_above_0_5 = int(0.005 * length)

# Generate values
values_above_0_5 = np.random.uniform(0.5, 1.0, num_above_0_5)
values_below_0_5 = np.random.uniform(0.0, 0.5, length - num_above_0_5)

# Combine and shuffle the array
random_array = np.concatenate((values_above_0_5, values_below_0_5))
np.random.shuffle(random_array)
print(random_array)
model_results_dict['random'] = (chr19_peaks,random_array)
# Out:
# [0.42024716 0.09396182 0.07517633 ... 0.05031284 0.16753352 0.4821399 ]

# %%
for name,(targets,probabilities) in model_results_dict.items():
    precision, recall, thresholds = precision_recall_curve(targets, probabilities)
    
    pr_auc = auc(recall, precision)
    if name=='4_channel':
        mod_name = 'seq only'
    elif name=='5_channel':
        mod_name = 'seq+methyl'
    elif name=='1_channel':
        mod_name = 'methyl only'
    else:
        mod_name = name
    label = mod_name+f" (auc {pr_auc:.3f})"
    plt.plot(recall,precision,label=label)
plt.legend()
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('chr19 all bins\nPrecision-Recall Curve - Comparing Models')
plt.show()
for name,(targets,probabilities) in model_results_dict.items():
    fpr,tpr,roc_thresholds = roc_curve(targets,probabilities)
    
    roc_auc = auc(fpr, tpr)
    if name=='4_channel':
        mod_name = 'seq only'
    elif name=='5_channel':
        mod_name = 'seq+methyl'
    elif name=='1_channel':
        mod_name = 'methyl only'
    else:
        mod_name = name
    label = mod_name+f" (auc {roc_auc:.3f})"
    plt.plot(fpr,tpr,label=label)
plt.legend()
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('chr19 all bins\nROC Curve - Comparing Models')
plt.show()

# %%
test_results_dict = {}
chr19_dataset = '/clusterfs/nilah/oberon/datasets/methylseq-net_deep-ctcf/test_th0.05_fd6d75e.h5'
for model_path in model_paths:
    name = Path(model_path).stem[-1]+"_channel"
    print(name)
    test_results_dict[name] = inference.run_whole_dataset(
        model_path,
        chr19_dataset,
    )
# Get the length of the existing array
length = len(chr19_peaks)

# Calculate the number of values that should be above 0.5
num_above_0_5 = int(0.02 * length)

# Generate values
values_above_0_5 = np.random.uniform(0.5, 1.0, num_above_0_5)
values_below_0_5 = np.random.uniform(0.0, 0.5, length - num_above_0_5)

# Combine and shuffle the array
random_array = np.concatenate((values_above_0_5, values_below_0_5))
np.random.shuffle(random_array)
print(random_array)
test_results_dict['random'] = (chr19_peaks,random_array)
# Out:
# 4_channel
# model passes:   0%|          | 0/363 [00:00<?, ?batch/s]
# 5_channel
# model passes:   0%|          | 0/363 [00:00<?, ?batch/s]
# 1_channel
# model passes:   0%|          | 0/363 [00:00<?, ?batch/s]
# [0.16898811 0.48727942 0.31095112 ... 0.49504929 0.41612725 0.3171492 ]

# %%
for name,(targets,probabilities) in test_results_dict.items():
    precision, recall, thresholds = precision_recall_curve(targets, probabilities)
    pr_auc = auc(recall, precision)
    if name=='4_channel':
        mod_name = 'seq only'
    elif name=='5_channel':
        mod_name = 'seq+methyl'
    elif name=='1_channel':
        mod_name = 'methyl only'
    else:
        mod_name = name
    label = mod_name+f" (auc {pr_auc:.3f})"
    plt.plot(recall,precision,label=label)
plt.legend()
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('chr18,chr19,chrX 98% negative 2% positive\nPrecision-Recall Curve - Comparing Models')
plt.show()
for name,(targets,probabilities) in test_results_dict.items():
    fpr,tpr,roc_thresholds = roc_curve(targets,probabilities)
    
    roc_auc = auc(fpr, tpr)
    if name=='4_channel':
        mod_name = 'seq only'
    elif name=='5_channel':
        mod_name = 'seq+methyl'
    elif name=='1_channel':
        mod_name = 'methyl only'
    else:
        mod_name = name
    label = mod_name+f" (auc {roc_auc:.3f})"
    plt.plot(fpr,tpr,label=label)
plt.legend()
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('chr18,chr19,chrX 98% negative 2% positive\nROC Curve - Comparing Models')
plt.show()
